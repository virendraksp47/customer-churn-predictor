# %%
import sys
from pathlib import Path
project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %%
    
def remove_num_outliers(df,col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %%
from src.utils import *

# remove outliers from numerical columns
df=load_data()

print("Data shape before removing outliers:", df.shape)

df=remove_num_outliers(df,"age")
df=remove_num_outliers(df,"credit_score")

print("Data shape after removing outliers:", df.shape)
# Out:
# Data shape before removing outliers: (10000, 12)
# Data shape after removing outliers: (9627, 12)
